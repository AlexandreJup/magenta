# %% [markdown]
# This is my script for music generation.
# You can choose how many steps the training should be.

# %%
import magenta
import magenta.music as mm

import tensorflow as tf


print (magenta.__version__ )
print (tf.__version__)
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
print ('🎉 Done!')
# Out:
# 1.1.2
# 1.14.0
# 🎉 Done!

# %% [markdown]
# # Generate a sequence

# %% [markdown]
# ### 1000 training steps model

# %%
bundle = mm.sequence_generator_bundle.read_bundle_file('polyphony_rnn/1000_steps_polyphony.mag')

# Import dependencies.
from magenta.models.polyphony_rnn import polyphony_sequence_generator
from magenta.protobuf import generator_pb2
from magenta.protobuf import music_pb2


# Initialize the model.
print ("Initializing model...")
generator_map = polyphony_sequence_generator.get_generator_map()
generator = generator_map['polyphony'](checkpoint=None, bundle=bundle)
generator.initialize()

print ('🎉 Done!')
# Out:
# W0718 19:30:35.720301 11488 deprecation_wrapper.py:119] From D:\alexa\documents\ema\Github\magenta\magenta\music\sequence_generator_bundle.py:30: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0718 19:30:36.773951 11488 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0718 19:30:36.801419 11488 deprecation_wrapper.py:119] From D:\alexa\documents\ema\Github\magenta\magenta\music\model.py:70: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
#Convert midi files to notesequence

seq=mm.midi_file_to_note_sequence('makers_raw/export.mid')
mm.plot_sequence(seq)
#mm.play_sequence(seq,synth=mm.fluidsynth)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1048">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5904b6d7-727d-4cea-a4af-923fba3bbec3" data-root-id="1001"></div>

# %%
# Model options. Change these to get different generated sequences! 

input_sequence = seq 
num_steps = 512 # change this for shorter or longer sequences
temperature =0.3 # the higher the temperature the more random the sequence.

# Set the start time to begin on the next step after the last note ends.
last_end_time = (max(n.end_time for n in input_sequence.notes)
                  if input_sequence.notes else 0)
qpm = input_sequence.tempos[0].qpm 
seconds_per_step = 60 / qpm / generator.steps_per_quarter
total_seconds = num_steps * seconds_per_step

generator_options = generator_pb2.GeneratorOptions()
generator_options.args['temperature'].float_value = temperature
generate_section = generator_options.generate_sections.add(
  start_time=last_end_time + seconds_per_step,
  end_time=total_seconds)

# Ask the model to continue the sequence.
creation = generator.generate(input_sequence, generator_options)


# Read the masterpiece
mm.plot_sequence(creation, show_figure=True)
#mm.play_sequence(creation,mm.midi_synth.synthesize)
mm.midi_io.note_sequence_to_midi_file(creation,'creation.mid')
# Out:
# W0718 19:34:30.882883 11488 deprecation_wrapper.py:119] From D:\alexa\documents\ema\Github\magenta\magenta\models\polyphony_rnn\polyphony_lib.py:366: The name tf.logging.debug is deprecated. Please use tf.compat.v1.logging.debug instead.
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1384">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="514cccb8-633b-476f-b794-35ba750c61d7" data-root-id="1337"></div>
